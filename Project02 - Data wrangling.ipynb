# %%
# Import neccessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Read Dataset
df1= pd.read_csv("dataset_1 - dataset_1.csv")
df1.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
df1.tail()
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 605  0.18
# 606  0.18
# 607  0.18
# 608  0.22
# 609  0.20

# %%
#information of dataset
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB

# %%
#shape of the dataset
df1.shape
# Out:
# (610, 10)

# %%
#Finding missing values
df1.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
#finding duplicate values in dataset
df1.duplicated().sum()
# Out:
# 0

# %%
#Identifying Garbage value
for i in df1.select_dtypes(include="object").columns:
    print(df1[i].value_counts())
    print("***"*10)
# Out:
# 01-01-2011    24
# 09-01-2011    24
# 21-01-2011    24
# 20-01-2011    24
# 17-01-2011    24
# 16-01-2011    24
# 13-01-2011    24
# 10-01-2011    24
# 15-01-2011    24
# 08-01-2011    24
# 05-01-2011    23
# 25-01-2011    23
# 24-01-2011    23
# 23-01-2011    23
# 22-01-2011    23
# 04-01-2011    23
# 19-01-2011    23
# 06-01-2011    23
# 02-01-2011    23
# 14-01-2011    23
# 07-01-2011    23
# 11-01-2011    22
# 03-01-2011    22
# 12-01-2011    22
# 26-01-2011    16
# 28-01-2011    15
# 18-01-2011    12
# 27-01-2011     8
# Name: dteday, dtype: int64
# ******************************

# %%
col=['dteday']
df1[col]= df1[col].apply(pd.to_numeric,args=('coerce',))

# %%
df1[col]
# Out:
#      dteday
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 605     NaN
# 606     NaN
# 607     NaN
# 608     NaN
# 609     NaN
#
# [610 rows x 1 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      0 non-null      float64
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(2), int64(7)
# memory usage: 43.6 KB

# %%
#Loading the Dataset2
df2=pd.read_excel("dataset_2.xlsx")
df2.head()
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
df2.tail()
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41

# %%
#shape
df2.shape
# Out:
# (610, 8)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.2 KB

# %%
#finding missing value in dataset2

df2.isnull().sum()
# Out:
# Unnamed: 0     0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
#finding duplicate
df2.duplicated().sum()
# Out:
# 0

# %%
#identify garbage value
for i in df2.select_dtypes(include="object").columns:
    print(df2[i].value_counts())
    print("***"*10)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.2 KB

# %%
#Merging dataset1 and dataset2

# %%
data=pd.merge(df1, df2, how='outer', on=['instant', 'instant'])

# %%
data.head()
# Out:
#    instant  dteday  season  yr  mnth  hr  holiday  weekday  weathersit  temp  \
# 0        1     NaN       1   0     1   0    False        6           1  0.24
# 1        2     NaN       1   0     1   1    False        6           1  0.22
# 2        3     NaN       1   0     1   2    False        6           1  0.22
# 3        4     NaN       1   0     1   3    False        6           1  0.24
# 4        5     NaN       1   0     1   4    False        6           1  0.24
#
#    Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt
# 0           0  0.2879  0.81        0.0       3          13   16
# 1           1  0.2727  0.80        0.0       8          32   40
# 2           2  0.2727  0.80        0.0       5          27   32
# 3           3  0.2879  0.75        0.0       3          10   13
# 4           4  0.2879  0.75        0.0       0           1    1

# %%
data.tail()
# Out:
#      instant  dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 605      606     NaN       1   0     1  11    False        5           3
# 606      607     NaN       1   0     1  12    False        5           3
# 607      608     NaN       1   0     1  13    False        5           3
# 608      609     NaN       1   0     1  14    False        5           3
# 609      610     NaN       1   0     1  15    False        5           2
#
#      temp  Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt
# 605  0.18         605  0.2121  0.93     0.1045       0          30   30
# 606  0.18         606  0.2121  0.93     0.1045       1          28   29
# 607  0.18         607  0.2121  0.93     0.1045       0          31   31
# 608  0.22         608  0.2727  0.80     0.0000       2          36   38
# 609  0.20         609  0.2576  0.86     0.0000       1          40   41

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 610 entries, 0 to 609
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      0 non-null      float64
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  Unnamed: 0  610 non-null    int64
#  11  atemp       599 non-null    float64
#  12  hum         610 non-null    float64
#  13  windspeed   610 non-null    float64
#  14  casual      610 non-null    int64
#  15  registered  610 non-null    int64
#  16  cnt         610 non-null    int64
# dtypes: bool(1), float64(5), int64(11)
# memory usage: 81.6 KB

# %%
data.shape
# Out:
# (610, 17)

# %%
data.isnull().sum()
# Out:
# instant         0
# dteday        610
# season          0
# yr              0
# mnth            0
# hr              0
# holiday         0
# weekday         0
# weathersit      0
# temp            0
# Unnamed: 0      0
# atemp          11
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
#identify garbage value
for i in data.select_dtypes(include="object").columns:
    print(data[i].value_counts())
    print("***"*10)

# %%
#Boxplot to identify the outlier

# %%
sns.boxplot(data['temp'])
# Out:
# <Axes: >

# %%
#removal of outliers
def removal_box_plot(data, column, threshold):
    sns.boxplot(data[column])
    plt.title(f'Original Box Plot of {column}')
    plt.show()
 
    removed_outliers = data[data[column] <= threshold]
 
    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers

threshold_value = 0.3
 
no_outliers = removal_box_plot(data, 'temp', threshold_value)

# %%
#missing value treatment

data.isnull().sum()
# Out:
# instant         0
# dteday        610
# season          0
# yr              0
# mnth            0
# hr              0
# holiday         0
# weekday         0
# weathersit      0
# temp            0
# Unnamed: 0      0
# atemp          11
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# dtype: int64

# %%
for i in["atemp"]:
    data[i].fillna(data[i].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# instant         0
# dteday        610
# season          0
# yr              0
# mnth            0
# hr              0
# holiday         0
# weekday         0
# weathersit      0
# temp            0
# Unnamed: 0      0
# atemp           0
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# dtype: int64

# %%
data.head()
# Out:
#    instant  dteday  season  yr  mnth  hr  holiday  weekday  weathersit  temp  \
# 0        1     NaN       1   0     1   0    False        6           1  0.24
# 1        2     NaN       1   0     1   1    False        6           1  0.22
# 2        3     NaN       1   0     1   2    False        6           1  0.22
# 3        4     NaN       1   0     1   3    False        6           1  0.24
# 4        5     NaN       1   0     1   4    False        6           1  0.24
#
#    Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt
# 0           0  0.2879  0.81        0.0       3          13   16
# 1           1  0.2727  0.80        0.0       8          32   40
# 2           2  0.2727  0.80        0.0       5          27   32
# 3           3  0.2879  0.75        0.0       3          10   13
# 4           4  0.2879  0.75        0.0       0           1    1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 610 entries, 0 to 609
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      0 non-null      float64
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  Unnamed: 0  610 non-null    int64
#  11  atemp       610 non-null    float64
#  12  hum         610 non-null    float64
#  13  windspeed   610 non-null    float64
#  14  casual      610 non-null    int64
#  15  registered  610 non-null    int64
#  16  cnt         610 non-null    int64
# dtypes: bool(1), float64(5), int64(11)
# memory usage: 97.8 KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 610 entries, 0 to 609
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      0 non-null      float64
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  Unnamed: 0  610 non-null    int64
#  11  atemp       610 non-null    float64
#  12  hum         610 non-null    float64
#  13  windspeed   610 non-null    float64
#  14  casual      610 non-null    int64
#  15  registered  610 non-null    int64
#  16  cnt         610 non-null    int64
# dtypes: bool(1), float64(5), int64(11)
# memory usage: 97.8 KB

# %%
data.head()
# Out:
#    instant  dteday  season  yr  mnth  hr  holiday  weekday  weathersit  temp  \
# 0        1     NaN       1   0     1   0    False        6           1  0.24
# 1        2     NaN       1   0     1   1    False        6           1  0.22
# 2        3     NaN       1   0     1   2    False        6           1  0.22
# 3        4     NaN       1   0     1   3    False        6           1  0.24
# 4        5     NaN       1   0     1   4    False        6           1  0.24
#
#    Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt
# 0           0  0.2879  0.81        0.0       3          13   16
# 1           1  0.2727  0.80        0.0       8          32   40
# 2           2  0.2727  0.80        0.0       5          27   32
# 3           3  0.2879  0.75        0.0       3          10   13
# 4           4  0.2879  0.75        0.0       0           1    1

# %%
#load dataset3

df3= pd.read_csv("dataset_3 - dataset_3.csv")
df3.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620  29-01-2011       1   0     1   1    False        6           1
# 1      621  29-01-2011       1   0     1   2    False        6           1
# 2      622  29-01-2011       1   0     1   3    False        6           1
# 3      623  29-01-2011       1   0     1   4    False        6           1
# 4      624  29-01-2011       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2

# %%
df3.tail()
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# 385  0.24  0.2273  0.70     0.1940       1          61   62
# 386  0.22  0.2273  0.75     0.1343       1          57   58
# 387  0.24  0.2121  0.65     0.3582       0          26   26
# 388  0.24  0.2273  0.60     0.2239       1          22   23
# 389  0.22  0.1970  0.64     0.3582       2          26   28

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    object
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), float64(4), int64(10), object(1)
# memory usage: 46.2+ KB

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
df3.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df3['dteday']=df3['dteday'].str.replace('-','').astype(float)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    float64
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), float64(5), int64(10)
# memory usage: 46.2 KB

# %%
#cocatinate the data and dataset3
concat = pd.concat([data, df3])

# %%
concat.head()
# Out:
#    instant  dteday  season  yr  mnth  hr  holiday  weekday  weathersit  temp  \
# 0        1     NaN       1   0     1   0    False        6           1  0.24
# 1        2     NaN       1   0     1   1    False        6           1  0.22
# 2        3     NaN       1   0     1   2    False        6           1  0.22
# 3        4     NaN       1   0     1   3    False        6           1  0.24
# 4        5     NaN       1   0     1   4    False        6           1  0.24
#
#    Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt
# 0         0.0  0.2879  0.81        0.0       3          13   16
# 1         1.0  0.2727  0.80        0.0       8          32   40
# 2         2.0  0.2727  0.80        0.0       5          27   32
# 3         3.0  0.2879  0.75        0.0       3          10   13
# 4         4.0  0.2879  0.75        0.0       0           1    1

# %%
concat1=concat.drop(['instant'],axis=1)
concat1.head()
# Out:
#    dteday  season  yr  mnth  hr  holiday  weekday  weathersit  temp  \
# 0     NaN       1   0     1   0    False        6           1  0.24
# 1     NaN       1   0     1   1    False        6           1  0.22
# 2     NaN       1   0     1   2    False        6           1  0.22
# 3     NaN       1   0     1   3    False        6           1  0.24
# 4     NaN       1   0     1   4    False        6           1  0.24
#
#    Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt
# 0         0.0  0.2879  0.81        0.0       3          13   16
# 1         1.0  0.2727  0.80        0.0       8          32   40
# 2         2.0  0.2727  0.80        0.0       5          27   32
# 3         3.0  0.2879  0.75        0.0       3          10   13
# 4         4.0  0.2879  0.75        0.0       0           1    1

# %%
concat1.isnull().sum()
# Out:
# dteday        610
# season          0
# yr              0
# mnth            0
# hr              0
# holiday         0
# weekday         0
# weathersit      0
# temp            0
# Unnamed: 0    390
# atemp           0
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# dtype: int64

# %%
concat1.isnull().sum()
# Out:
# dteday        610
# season          0
# yr              0
# mnth            0
# hr              0
# holiday         0
# weekday         0
# weathersit      0
# temp            0
# Unnamed: 0    390
# atemp           0
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# dtype: int64

# %%
concat2=concat1.drop(['Unnamed: 0','dteday'],axis=1)
concat2.head()
# Out:
#    season  yr  mnth  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0       1   0     1   0    False        6           1  0.24  0.2879  0.81
# 1       1   0     1   1    False        6           1  0.22  0.2727  0.80
# 2       1   0     1   2    False        6           1  0.22  0.2727  0.80
# 3       1   0     1   3    False        6           1  0.24  0.2879  0.75
# 4       1   0     1   4    False        6           1  0.24  0.2879  0.75
#
#    windspeed  casual  registered  cnt
# 0        0.0       3          13   16
# 1        0.0       8          32   40
# 2        0.0       5          27   32
# 3        0.0       3          10   13
# 4        0.0       0           1    1

# %% [markdown]
# concat2.info()

# %%
concat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 389
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      1000 non-null   int64
#  1   yr          1000 non-null   int64
#  2   mnth        1000 non-null   int64
#  3   hr          1000 non-null   int64
#  4   holiday     1000 non-null   bool
#  5   weekday     1000 non-null   int64
#  6   weathersit  1000 non-null   int64
#  7   temp        1000 non-null   float64
#  8   atemp       1000 non-null   float64
#  9   hum         1000 non-null   float64
#  10  windspeed   1000 non-null   float64
#  11  casual      1000 non-null   int64
#  12  registered  1000 non-null   int64
#  13  cnt         1000 non-null   int64
# dtypes: bool(1), float64(4), int64(9)
# memory usage: 110.4 KB

# %%
#skewness
concat2.skew()
# Out:
# season        0.000000
# yr            0.000000
# mnth          0.812772
# hr           -0.063524
# holiday       6.229578
# weekday       0.021925
# weathersit    1.044098
# temp          0.547997
# atemp         0.435927
# hum           0.436893
# windspeed     0.433675
# casual        3.414105
# registered    1.296723
# cnt           1.137709
# dtype: float64

# %%
#corelation
print(concat2['temp'].corr(concat['hum']))
# Out:
# 0.08072014716281216

# %%
print(concat2['windspeed'].corr(concat['temp']))
# Out:
# 0.12262532562998449

# %%
#outliers

# %%
sns.boxplot(concat2['hum'])
# Out:
# <Axes: >

# %%
sns.boxplot(concat2['temp'])
# Out:
# <Axes: >

# %%
sns.boxplot(concat2['casual'])
# Out:
# <Axes: >

# %%
#removal of outliers
def removal_box_plot(concat2, column, threshold):
    sns.boxplot(concat2[column])
    plt.title(f'Original Box Plot of {column}')
    plt.show()
 
    removed_outliers = data[concat2[column] <= threshold]
 
    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers

threshold_value = 30
 
no_outliers = removal_box_plot(data, 'casual', threshold_value)

# %%
concat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 389
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      1000 non-null   int64
#  1   yr          1000 non-null   int64
#  2   mnth        1000 non-null   int64
#  3   hr          1000 non-null   int64
#  4   holiday     1000 non-null   bool
#  5   weekday     1000 non-null   int64
#  6   weathersit  1000 non-null   int64
#  7   temp        1000 non-null   float64
#  8   atemp       1000 non-null   float64
#  9   hum         1000 non-null   float64
#  10  windspeed   1000 non-null   float64
#  11  casual      1000 non-null   int64
#  12  registered  1000 non-null   int64
#  13  cnt         1000 non-null   int64
# dtypes: bool(1), float64(4), int64(9)
# memory usage: 142.6 KB

# %%
concat2.head()
# Out:
#    season  yr  mnth  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0       1   0     1   0    False        6           1  0.24  0.2879  0.81
# 1       1   0     1   1    False        6           1  0.22  0.2727  0.80
# 2       1   0     1   2    False        6           1  0.22  0.2727  0.80
# 3       1   0     1   3    False        6           1  0.24  0.2879  0.75
# 4       1   0     1   4    False        6           1  0.24  0.2879  0.75
#
#    windspeed  casual  registered  cnt
# 0        0.0       3          13   16
# 1        0.0       8          32   40
# 2        0.0       5          27   32
# 3        0.0       3          10   13
# 4        0.0       0           1    1
