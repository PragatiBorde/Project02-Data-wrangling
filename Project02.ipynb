# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("dataset_1 - dataset_1.csv")
df1.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
df2=pd.read_excel("dataset_2.xlsx")
df2.head()
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
data=pd.merge(df1, df2, how='outer', on=['instant', 'instant'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 610 entries, 0 to 609
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  Unnamed: 0  610 non-null    int64
#  11  atemp       599 non-null    float64
#  12  hum         610 non-null    float64
#  13  windspeed   610 non-null    float64
#  14  casual      610 non-null    int64
#  15  registered  610 non-null    int64
#  16  cnt         610 non-null    int64
# dtypes: bool(1), float64(4), int64(11), object(1)
# memory usage: 81.6+ KB

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# Unnamed: 0     0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
data.describe()
# Out:
#           instant  season     yr   mnth          hr     weekday  weathersit  \
# count  610.000000   610.0  610.0  610.0  610.000000  610.000000  610.000000
# mean   305.500000     1.0    0.0    1.0   11.795082    2.977049    1.477049
# std    176.236111     0.0    0.0    0.0    6.852107    2.054943    0.643496
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000    1.000000
# 25%    153.250000     1.0    0.0    1.0    6.000000    1.000000    1.000000
# 50%    305.500000     1.0    0.0    1.0   12.000000    3.000000    1.000000
# 75%    457.750000     1.0    0.0    1.0   18.000000    5.000000    2.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000    4.000000
#
#              temp  Unnamed: 0       atemp         hum   windspeed      casual  \
# count  610.000000  610.000000  599.000000  610.000000  610.000000  610.000000
# mean     0.196885  304.500000    0.199935    0.562475    0.204851    4.501639
# ...

# %%
data.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp  Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24           0  0.2879  0.81        0.0       3          13   16
# 1  0.22           1  0.2727  0.80        0.0       8          32   40
# 2  0.22           2  0.2727  0.80        0.0       5          27   32
# 3  0.24           3  0.2879  0.75        0.0       3          10   13
# 4  0.24           4  0.2879  0.75        0.0       0           1    1

# %%
data.shape
# Out:
# (610, 17)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(data['temp'])
# Out:
# <Axes: >

# %%
sns.boxplot(data['hum'])
# Out:
# <Axes: >

# %%
sns.boxplot(data['casual'])
# Out:
# <Axes: >

# %%
#removal of outliers
def removal_box_plot(data, column, threshold):
    sns.boxplot(data[column])
    plt.title(f'Original Box Plot of {column}')
    plt.show()
 
    removed_outliers = data[data[column] <= threshold]
 
    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers

threshold_value = 0.3
 
no_outliers = removal_box_plot(data, 'temp', threshold_value)

# %%
data.skew()
# Out:
# C:\Users\Pragati\AppData\Local\Temp\ipykernel_14456\1188251951.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.skew()
# instant       0.000000
# season        0.000000
# yr            0.000000
# mnth          0.000000
# hr           -0.072059
# holiday       4.750637
# weekday       0.026403
# weathersit    1.050244
# temp          0.665087
# Unnamed: 0    0.000000
# atemp         0.555599
# hum           0.609553
# windspeed     0.339029
# casual        2.712869
# registered    1.428875
# cnt           1.243563
# dtype: float64

# %%
data.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp  Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24           0  0.2879  0.81        0.0       3          13   16
# 1  0.22           1  0.2727  0.80        0.0       8          32   40
# 2  0.22           2  0.2727  0.80        0.0       5          27   32
# 3  0.24           3  0.2879  0.75        0.0       3          10   13
# 4  0.24           4  0.2879  0.75        0.0       0           1    1

# %%
df_encode=data.copy()

# %%
df_encode=pd.get_dummies(data=df_encode,columns=['holiday'])

# %%
df_encode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 610 entries, 0 to 609
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   instant        610 non-null    int64
#  1   dteday         610 non-null    object
#  2   season         610 non-null    int64
#  3   yr             610 non-null    int64
#  4   mnth           610 non-null    int64
#  5   hr             610 non-null    int64
#  6   weekday        610 non-null    int64
#  7   weathersit     610 non-null    int64
#  8   temp           610 non-null    float64
#  9   Unnamed: 0     610 non-null    int64
#  10  atemp          599 non-null    float64
#  11  hum            610 non-null    float64
#  12  windspeed      610 non-null    float64
#  13  casual         610 non-null    int64
#  14  registered     610 non-null    int64
#  15  cnt            610 non-null    int64
#  16  holiday_False  610 non-null    uint8
#  17  holiday_True   610 non-null    uint8
# ...

# %%
df_encode.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  weekday  weathersit  temp  \
# 0        1  01-01-2011       1   0     1   0        6           1  0.24
# 1        2  01-01-2011       1   0     1   1        6           1  0.22
# 2        3  01-01-2011       1   0     1   2        6           1  0.22
# 3        4  01-01-2011       1   0     1   3        6           1  0.24
# 4        5  01-01-2011       1   0     1   4        6           1  0.24
#
#    Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt  \
# 0           0  0.2879  0.81        0.0       3          13   16
# 1           1  0.2727  0.80        0.0       8          32   40
# 2           2  0.2727  0.80        0.0       5          27   32
# 3           3  0.2879  0.75        0.0       3          10   13
# 4           4  0.2879  0.75        0.0       0           1    1
#
#    holiday_False  holiday_True
# 0              1             0
# 1              1             0
# 2              1             0
# ...

# %%
df_encode.drop(['instant','Unnamed: 0'],axis=1)
# Out:
#          dteday  season  yr  mnth  hr  weekday  weathersit  temp   atemp  \
# 0    01-01-2011       1   0     1   0        6           1  0.24  0.2879
# 1    01-01-2011       1   0     1   1        6           1  0.22  0.2727
# 2    01-01-2011       1   0     1   2        6           1  0.22  0.2727
# 3    01-01-2011       1   0     1   3        6           1  0.24  0.2879
# 4    01-01-2011       1   0     1   4        6           1  0.24  0.2879
# ..          ...     ...  ..   ...  ..      ...         ...   ...     ...
# 605  28-01-2011       1   0     1  11        5           3  0.18  0.2121
# 606  28-01-2011       1   0     1  12        5           3  0.18  0.2121
# 607  28-01-2011       1   0     1  13        5           3  0.18  0.2121
# 608  28-01-2011       1   0     1  14        5           3  0.22  0.2727
# 609  28-01-2011       1   0     1  15        5           2  0.20  0.2576
#
#       hum  windspeed  casual  registered  cnt  holiday_False  holiday_True
# ...

# %%
df_encode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 610 entries, 0 to 609
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   instant        610 non-null    int64
#  1   dteday         610 non-null    object
#  2   season         610 non-null    int64
#  3   yr             610 non-null    int64
#  4   mnth           610 non-null    int64
#  5   hr             610 non-null    int64
#  6   weekday        610 non-null    int64
#  7   weathersit     610 non-null    int64
#  8   temp           610 non-null    float64
#  9   Unnamed: 0     610 non-null    int64
#  10  atemp          599 non-null    float64
#  11  hum            610 non-null    float64
#  12  windspeed      610 non-null    float64
#  13  casual         610 non-null    int64
#  14  registered     610 non-null    int64
#  15  cnt            610 non-null    int64
#  16  holiday_False  610 non-null    uint8
#  17  holiday_True   610 non-null    uint8
# ...

# %%
df3=pd.read_csv("dataset_3 - dataset_3.csv")

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    object
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), float64(4), int64(10), object(1)
# memory usage: 46.2+ KB

# %%
df3.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620  29-01-2011       1   0     1   1    False        6           1
# 1      621  29-01-2011       1   0     1   2    False        6           1
# 2      622  29-01-2011       1   0     1   3    False        6           1
# 3      623  29-01-2011       1   0     1   4    False        6           1
# 4      624  29-01-2011       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2

# %%
concat = pd.concat([df_encode, df3])

# %%
concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 389
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   instant        1000 non-null   int64
#  1   dteday         1000 non-null   object
#  2   season         1000 non-null   int64
#  3   yr             1000 non-null   int64
#  4   mnth           1000 non-null   int64
#  5   hr             1000 non-null   int64
#  6   weekday        1000 non-null   int64
#  7   weathersit     1000 non-null   int64
#  8   temp           1000 non-null   float64
#  9   Unnamed: 0     610 non-null    float64
#  10  atemp          989 non-null    float64
#  11  hum            1000 non-null   float64
#  12  windspeed      1000 non-null   float64
#  13  casual         1000 non-null   int64
#  14  registered     1000 non-null   int64
#  15  cnt            1000 non-null   int64
#  16  holiday_False  610 non-null    float64
# ...

# %%
concat.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  weekday  weathersit  temp  \
# 0        1  01-01-2011       1   0     1   0        6           1  0.24
# 1        2  01-01-2011       1   0     1   1        6           1  0.22
# 2        3  01-01-2011       1   0     1   2        6           1  0.22
# 3        4  01-01-2011       1   0     1   3        6           1  0.24
# 4        5  01-01-2011       1   0     1   4        6           1  0.24
#
#    Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt  \
# 0         0.0  0.2879  0.81        0.0       3          13   16
# 1         1.0  0.2727  0.80        0.0       8          32   40
# 2         2.0  0.2727  0.80        0.0       5          27   32
# 3         3.0  0.2879  0.75        0.0       3          10   13
# 4         4.0  0.2879  0.75        0.0       0           1    1
#
#    holiday_False  holiday_True holiday
# 0            1.0           0.0     NaN
# 1            1.0           0.0     NaN
# ...

# %%
concat.drop(['instant','Unnamed: 0'],axis=1)
# Out:
# C:\Users\Pragati\anaconda3\lib\site-packages\IPython\lib\pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# C:\Users\Pragati\anaconda3\lib\site-packages\IPython\core\formatters.py:342: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#          dteday  season  yr  mnth  hr  weekday  weathersit  temp   atemp  \
# 0    01-01-2011       1   0     1   0        6           1  0.24  0.2879
# 1    01-01-2011       1   0     1   1        6           1  0.22  0.2727
# 2    01-01-2011       1   0     1   2        6           1  0.22  0.2727
# 3    01-01-2011       1   0     1   3        6           1  0.24  0.2879
# 4    01-01-2011       1   0     1   4        6           1  0.24  0.2879
# ...

# %%
concat.isnull().sum()
# Out:
# instant            0
# dteday             0
# season             0
# yr                 0
# mnth               0
# hr                 0
# weekday            0
# weathersit         0
# temp               0
# Unnamed: 0       390
# atemp             11
# hum                0
# windspeed          0
# casual             0
# registered         0
# cnt                0
# holiday_False    390
# holiday_True     390
# holiday          610
# dtype: int64

# %%
concat.duplicated().sum()
# Out:
# 0

# %%
concat.skew()
# Out:
# C:\Users\Pragati\AppData\Local\Temp\ipykernel_14456\433987674.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   concat.skew()
# instant          0.000000
# season           0.000000
# yr               0.000000
# mnth             0.812772
# hr              -0.063524
# weekday          0.021925
# weathersit       1.044098
# temp             0.547997
# Unnamed: 0       0.000000
# atemp            0.455319
# hum              0.436893
# windspeed        0.433675
# casual           3.414105
# registered       1.296723
# cnt              1.137709
# holiday_False   -4.755016
# holiday_True     4.755016
# holiday          0.000000
# dtype: float64

# %%
sns.boxplot(data['hr'])
# Out:
# <Axes: >

# %%
sns.boxplot(data['temp'])
# Out:
# <Axes: >

# %%
#removal of outliers
def removal_box_plot(data, column, threshold):
    sns.boxplot(data[column])
    plt.title(f'Original Box Plot of {column}')
    plt.show()
 
    removed_outliers = data[data[column] <= threshold]
 
    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers

threshold_value = 0.3
 
no_outliers = removal_box_plot(data, 'temp', threshold_value)

# %%
concat.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  weekday  weathersit  temp  \
# 0        1  01-01-2011       1   0     1   0        6           1  0.24
# 1        2  01-01-2011       1   0     1   1        6           1  0.22
# 2        3  01-01-2011       1   0     1   2        6           1  0.22
# 3        4  01-01-2011       1   0     1   3        6           1  0.24
# 4        5  01-01-2011       1   0     1   4        6           1  0.24
#
#    Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt  \
# 0         0.0  0.2879  0.81        0.0       3          13   16
# 1         1.0  0.2727  0.80        0.0       8          32   40
# 2         2.0  0.2727  0.80        0.0       5          27   32
# 3         3.0  0.2879  0.75        0.0       3          10   13
# 4         4.0  0.2879  0.75        0.0       0           1    1
#
#    holiday_False  holiday_True holiday
# 0            1.0           0.0     NaN
# 1            1.0           0.0     NaN
# ...
